# %% [markdown]
# <a href="https://colab.research.google.com/github/iAbhyuday/AI-playground/blob/master/st_reid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -r Spatial-Temporal-Re-identification/

# %%
# !git clone https://github.com/Wanggcong/Spatial-Temporal-Re-identification.git
# Out:
# Cloning into 'Spatial-Temporal-Re-identification'...
# remote: Enumerating objects: 112, done.
# remote: Total 112 (delta 0), reused 0 (delta 0), pack-reused 112
# Receiving objects: 100% (112/112), 39.43 KiB | 19.71 MiB/s, done.
# Resolving deltas: 100% (66/66), done.

# %%
# !mkdir Spatial-Temporal-Re-identification/osnet

# %%
# !cp -r Market-1501-v15.09.15 Spatial-Temporal-Re-identification/raw-dataset

# %%
# !wget http://188.138.127.15:81/Datasets/Market-1501-v15.09.15.zip
# Out:
# --2021-03-28 18:01:38--  http://188.138.127.15:81/Datasets/Market-1501-v15.09.15.zip
# Connecting to 188.138.127.15:81... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 152733771 (146M) [application/zip]
# Saving to: ‘Market-1501-v15.09.15.zip’
#
# Market-1501-v15.09. 100%[===================>] 145.66M  12.3MB/s    in 13s
#
# 2021-03-28 18:01:51 (11.4 MB/s) - ‘Market-1501-v15.09.15.zip’ saved [152733771/152733771]

# %%
# !unzip -q Market-1501-v15.09.15.zip 
# !mkdir Spatial-Temporal-Re-identification/raw-dataset
# !cp -r Market-1501-v15.09.15 Spatial-Temporal-Re-identification/raw-dataset

# %%
# !python3 Spatial-Temporal-Re-identification/prepare.py --Market
# Out:
# Done!

# %%
# !python3 Spatial-Temporal-Re-identification/test_osnet.py --test_dir "/content/Spatial-Temporal-Re-identification/dataset/market_rename"
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:258: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# -------test-----------
# 32
# 64
# 96
# 128
# 160
# 192
# 224
# 256
# 288
# 320
# 352
# 384
# 416
# 448
# 480
# 512
# 544
# 576
# 608
# 640
# 672
# 704
# 736
# 768
# 800
# 832
# 864
# 896
# 928
# 960
# 992
# 1024
# 1056
# 1088
# 1120
# 1152
# 1184
# ...

# %%
# !python3 Spatial-Temporal-Re-identification/gen_st_model_market.py  --data_dir "/content/Spatial-Temporal-Re-identification/dataset/market_rename"

# %%
# !python3 Spatial-Temporal-Re-identification/evaluate_st.py
# Out:
# query_feature: (3368, 512)
# gallery_feature: (19732, 512)
# gauss 0->0
# gauss 0->1
# gauss 0->2
# gauss 0->3
# gauss 0->4
# gauss 0->5
# gauss 0->6
# gauss 0->7
# gauss 1->0
# gauss 1->1
# gauss 1->2
# gauss 1->3
# gauss 1->4
# gauss 1->5
# gauss 1->6
# gauss 1->7
# gauss 2->0
# gauss 2->1
# gauss 2->2
# gauss 2->3
# gauss 2->4
# gauss 2->5
# gauss 2->6
# gauss 2->7
# gauss 3->0
# gauss 3->1
# gauss 3->2
# gauss 3->3
# gauss 3->4
# gauss 3->5
# gauss 3->6
# gauss 3->7
# gauss 4->0
# gauss 4->1
# gauss 4->2
# gauss 4->3
# gauss 4->4
# gauss 4->5
# gauss 4->6
# gauss 4->7
# gauss 5->0
# gauss 5->1
# gauss 5->2
# gauss 5->3
# gauss 5->4
# gauss 5->5
# gauss 5->6
# gauss 5->7
# gauss 6->0
# gauss 6->1
# gauss 6->2
# gauss 6->3
# gauss 6->4
# gauss 6->5
# gauss 6->6
# gauss 6->7
# gauss 7->0
# gauss 7->1
# gauss 7->2
# gauss 7->3
# gauss 7->4
# gauss 7->5
# gauss 7->6
# gauss 7->7
# 0 tensor(1, dtype=torch.int32)
# 1 tensor(1, dtype=torch.int32)
# 2 tensor(1, dtype=torch.int32)
# ...

# %%
# !python3 Spatial-Temporal-Re-identification/visualize.py --test_dir "/content/Spatial-Temporal-Re-identification/dataset/market_rename" --query_index 765
# Out:
# query_feature: (3368, 512)
# gallery_feature: (19732, 512)
# /content/Spatial-Temporal-Re-identification/dataset/market_rename/query/0336/0336_c1_f0077797_00.jpg
# Top 10 images are as follow:
# /content/Spatial-Temporal-Re-identification/dataset/market_rename/gallery/0336/0336_c5_f0077898_03.jpg
# /content/Spatial-Temporal-Re-identification/dataset/market_rename/gallery/0336/0336_c5_f0077948_03.jpg
# /content/Spatial-Temporal-Re-identification/dataset/market_rename/gallery/0336/0336_c5_f0078098_03.jpg
# /content/Spatial-Temporal-Re-identification/dataset/market_rename/gallery/0336/0336_c5_f0077923_03.jpg
# /content/Spatial-Temporal-Re-identification/dataset/market_rename/gallery/0336/0336_c3_f0077592_03.jpg
# /content/Spatial-Temporal-Re-identification/dataset/market_rename/gallery/0336/0336_c3_f0077517_01.jpg
# /content/Spatial-Temporal-Re-identification/dataset/market_rename/gallery/0336/0336_c3_f0077667_01.jpg
# ...
